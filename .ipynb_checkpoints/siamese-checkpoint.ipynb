# %%
# %matplotlib inline
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import time
import random
import torch
from torch.autograd import Variable   
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from itertools import islice
from torch.utils.data import DataLoader,Dataset

# %%
CUDA_FLAG = torch.cuda.is_available()
print(CUDA_FLAG)
# Out:
# True

# %%
SEED = 1
torch.manual_seed(SEED)
if CUDA_FLAG:
    torch.cuda.manual_seed(SEED)

# SEQ_LEN = 151
# EMBEDDING_LEN = 151
# DATA_SET = 'Qiita_10052'
# TRAIN_NUM_EXAMPLE = 500000
# TEST_NUM_EXAMPLE = 10000
# EVAL_N = 2000

# SEQ_LEN = 465
# EMBEDDING_LEN = 465
# DATA_SET = 'RT988'
# TRAIN_NUM_EXAMPLE = 500000
# TEST_NUM_EXAMPLE = 10000
# EVAL_N = 2000

class Config():
    train_data_fp = './{}/siamese/pair_shuffle.fa'.format(DATA_SET)
    train_target_fp = './{}/siamese/dist_shuffle.txt'.format(DATA_SET)
    train_num_example = TRAIN_NUM_EXAMPLE
    train_batch_size = 100
    test_data_fp = './{}/siamese/testing_pair.fa'.format(DATA_SET)
    test_target_fp = './{}/siamese/testing_dist.txt'.format(DATA_SET)
    test_num_example = TEST_NUM_EXAMPLE
    test_batch_size = 1000
#     num_epoch = 20
#     num_epoch = 200
    learning_rate = 1e-4

# %%
class MaxMinout(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, embedding1, embedding2):
        shape = list(embedding1.size())
        flat1 = embedding1.view(1, -1)
        flat2 = embedding2.view(1, -1)
        combined = torch.cat((flat1, flat2), 0)
        maxout = combined.max(0)[0].view(*shape)
        # minout = combined.min(0)[0].view(*shape)
        minout = ((combined * -1).max(0)[0].view(*shape) * -1) # workaround for memory leak bug

        return maxout, minout

class SiameseNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.maxminout = MaxMinout()
        self.cnn = nn.Sequential(
            nn.Conv1d(4, 16, kernel_size=5, padding=2),
            nn.MaxPool1d(2),
            nn.ReLU(),
                
            nn.Conv1d(16, 32, kernel_size=5, padding=2),
            nn.MaxPool1d(2),
            nn.ReLU(),
               
            nn.Conv1d(32, 48, kernel_size=5, padding=2),
            nn.MaxPool1d(2),
            nn.ReLU(),
        )
        max_pooling_len = SEQ_LEN 
        max_pooling_len = np.floor((max_pooling_len - 2) / 2 + 1)
        max_pooling_len = np.floor((max_pooling_len - 2) / 2 + 1)
        max_pooling_len = np.floor((max_pooling_len - 2) / 2 + 1)
        self.fc = nn.Sequential(
#             nn.Dropout(0.8),
            nn.Linear(int(48 * max_pooling_len), EMBEDDING_LEN),
        )

    def forward_one_side(self, x):
        output = self.cnn(x)
        output = output.view(output.size()[0], -1)
        output = self.fc(output)
        return output

    def forward(self, input1, input2):
        embedding1 = self.forward_one_side(input1)
        embedding2 = self.forward_one_side(input2)
        maxout, minout = self.maxminout(embedding1, embedding2)
        return maxout, minout

# %%
def weight_func(dist):
    return 1.0
#     return 50.0 if dist < 0.2 else 1.0

class ContrastiveLoss(torch.nn.Module):
    def __init__(self):
        super().__init__()
        
    def forward(self, maxout, minout, align_dist):
        weight = Variable(torch.FloatTensor([weight_func(x) for x in align_dist.data]), requires_grad=False)
        if CUDA_FLAG:
            weight = weight.cuda()
        loss_contrastive = torch.mean(torch.mul(weight, torch.pow(1 - minout.sum(1)/maxout.sum(1) - align_dist, 2)))

        return loss_contrastive

# %%
atcg_map = {'A': 0, 'T': 1, 'C': 2, 'G': 3}

class SiameseNetworkDataset(Dataset):
    def __init__(self, data_fp, target_fp, N):
        self.data_fp = data_fp
        self.target_fp = target_fp
        self.N = N
        self.data_tensor = self.gen_data_tensor()
        self.target_tensor = self.gen_target_tensor()
        
    def __getitem__(self, index):
        return self.data_tensor[0][index], self.data_tensor[1][index], self.target_tensor[index]

    def __len__(self):
        return self.N
    
    def gen_data_tensor(self):
        seq1 = torch.zeros((self.N, 4, SEQ_LEN))
        seq2 = torch.zeros((self.N, 4, SEQ_LEN))
        cnt = 0
        with open(self.data_fp) as f:
            while True:
                next_n = list(islice(f, 4))
                if not next_n:
                    break
                if cnt >= self.N:
                    break
                read1 = next_n[1].strip()
                read2 = next_n[3].strip()
                for i, c in enumerate(read1):
                    seq1[cnt, atcg_map.get(c, 0), i] = 1.0
                for i, c in enumerate(read2):
                    seq2[cnt, atcg_map.get(c, 0), i] = 1.0
                cnt += 1
        return seq1, seq2

    def gen_target_tensor(self):
        target = torch.zeros(self.N)
        with open(self.target_fp) as f:
            for i, line in enumerate(f):
                if i >= self.N:
                    break
                pair_id, dist = line.strip().split()
                target[i] = float(dist)
        return target

# %%
net = SiameseNetwork()    
if CUDA_FLAG:
    net.cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(), lr=Config.learning_rate)
print(net)

training_dataset = SiameseNetworkDataset(Config.train_data_fp, 
                                         Config.train_target_fp,
                                         Config.train_num_example)

testing_dataset = SiameseNetworkDataset(Config.test_data_fp, 
                                        Config.test_target_fp,
                                        Config.test_num_example)

training_loader = DataLoader(
    dataset=training_dataset,      
    batch_size=Config.train_batch_size,      
    shuffle=True,              
    num_workers=4,              
)

testing_loader = DataLoader(
    dataset=testing_dataset,      
    batch_size=Config.test_batch_size,      
    shuffle=True,              
    num_workers=4,              
)
# Out:
# SiameseNetwork (
#   (maxminout): MaxMinout (
#   )
#   (cnn): Sequential (
#     (0): Conv1d(4, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): MaxPool1d (size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU ()
#     (3): Conv1d(16, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (4): MaxPool1d (size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU ()
#     (6): Conv1d(32, 48, kernel_size=(5,), stride=(1,), padding=(2,))
#     (7): MaxPool1d (size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): ReLU ()
#   )
#   (fc): Sequential (
#     (0): Linear (864 -> 80)
#   )
# )

# %%
plt.figure()
plt.hist(training_dataset.gen_target_tensor().numpy(), bins=100);
plt.figure()
plt.hist(testing_dataset.gen_target_tensor().numpy(), bins=100);

# %%
train_num_batch = int(np.ceil(Config.train_num_example / Config.train_batch_size))
test_num_batch = int(np.ceil(Config.test_num_example / Config.test_batch_size))
train_batch_interval = Config.train_num_example // Config.train_batch_size // 10
train_loss_hist = []
test_loss_hist = []

for epoch in range(Config.num_epoch):
    print('===========>')
#     net.train()
    train_running_loss = 0
    for batch_index, (train_seq1, train_seq2, train_target) in enumerate(training_loader):
        if CUDA_FLAG:
            train_seq1 = train_seq1.cuda()
            train_seq2 = train_seq2.cuda()
            train_target = train_target.cuda()
        train_seq1 = Variable(train_seq1)
        train_seq2 = Variable(train_seq2)
        train_target = Variable(train_target).float()
        train_output1, train_output2 = net(train_seq1, train_seq2)
        train_loss_contrastive = criterion(train_output1, train_output2, train_target)
        train_running_loss += train_loss_contrastive.data[0]
        
        if batch_index % train_batch_interval == train_batch_interval - 1:
            print('Epoch: {:d}/{:d}, Batch: {:d}/{:d}\n'
                  'Accumulated loss: {:.4e}'.format(
                  epoch + 1, Config.num_epoch, 
                  batch_index + 1, train_num_batch, 
                  train_running_loss / (batch_index + 1)))
            
        optimizer.zero_grad()
        train_loss_contrastive.backward()
        optimizer.step() 
    train_loss = train_running_loss / train_num_batch
    train_loss_hist.append(train_loss)
    print('Train loss: {:.4e}'.format(train_loss))
    
#     net.eval()
    test_running_loss = 0
    for batch_index, (test_seq1, test_seq2, test_target) in enumerate(testing_loader):
        if CUDA_FLAG:
            test_seq1 = test_seq1.cuda()
            test_seq2 = test_seq2.cuda()
            test_target = test_target.cuda()
        test_seq1 = Variable(test_seq1)
        test_seq2 = Variable(test_seq2)
        test_target = Variable(test_target).float()
        test_output1, test_output2 = net(test_seq1, test_seq2)
        test_loss_contrastive = criterion(test_output1, test_output2, test_target)
        test_running_loss += test_loss_contrastive.data[0]
    print(test_output1.size())  
    
    test_loss = test_running_loss / test_num_batch
    test_loss_hist.append(test_loss)
    print('Test loss: {:.4e}'.format(test_loss))
# Out:
# ===========>
# Epoch: 1/20, Batch: 500/5000
# Accumulated loss: 4.7298e-03
# Epoch: 1/20, Batch: 1000/5000
# Accumulated loss: 2.8967e-03
# Epoch: 1/20, Batch: 1500/5000
# Accumulated loss: 2.2202e-03
# Epoch: 1/20, Batch: 2000/5000
# Accumulated loss: 1.8499e-03
# Epoch: 1/20, Batch: 2500/5000
# Accumulated loss: 1.6128e-03
# Epoch: 1/20, Batch: 3000/5000
# Accumulated loss: 1.4453e-03
# Epoch: 1/20, Batch: 3500/5000
# Accumulated loss: 1.3197e-03
# Epoch: 1/20, Batch: 4000/5000
# Accumulated loss: 1.2221e-03
# Epoch: 1/20, Batch: 4500/5000
# Accumulated loss: 1.1430e-03
# Epoch: 1/20, Batch: 5000/5000
# Accumulated loss: 1.0778e-03
# Train loss: 1.0778e-03
# torch.Size([1000, 80])
# Test loss: 6.2518e-04
# ===========>
# Epoch: 2/20, Batch: 500/5000
# Accumulated loss: 4.5490e-04
# Epoch: 2/20, Batch: 1000/5000
# Accumulated loss: 4.4641e-04
# Epoch: 2/20, Batch: 1500/5000
# Accumulated loss: 4.4269e-04
# Epoch: 2/20, Batch: 2000/5000
# Accumulated loss: 4.3612e-04
# Epoch: 2/20, Batch: 2500/5000
# Accumulated loss: 4.2965e-04
# Epoch: 2/20, Batch: 3000/5000
# Accumulated loss: 4.2531e-04
# Epoch: 2/20, Batch: 3500/5000
# Accumulated loss: 4.2069e-04
# Epoch: 2/20, Batch: 4000/5000
# Accumulated loss: 4.1598e-04
# Epoch: 2/20, Batch: 4500/5000
# Accumulated loss: 4.1212e-04
# Epoch: 2/20, Batch: 5000/5000
# Accumulated loss: 4.0800e-04
# Train loss: 4.0800e-04
# torch.Size([1000, 80])
# Test loss: 5.1796e-04
# ===========>
# Epoch: 3/20, Batch: 500/5000
# Epoch: 6/20, Batch: 3500/5000
# Accumulated loss: 2.6029e-04
# Epoch: 6/20, Batch: 4000/5000
# Accumulated loss: 2.6063e-04
# Epoch: 6/20, Batch: 4500/5000
# Accumulated loss: 2.6077e-04
# Epoch: 6/20, Batch: 5000/5000
# Accumulated loss: 2.6071e-04
# Train loss: 2.6071e-04
# torch.Size([1000, 80])
# Test loss: 4.4036e-04
# ===========>
# Epoch: 7/20, Batch: 500/5000
# Accumulated loss: 2.4644e-04
# Epoch: 7/20, Batch: 1000/5000
# Accumulated loss: 2.4677e-04
# Epoch: 7/20, Batch: 1500/5000
# Accumulated loss: 2.4841e-04
# Epoch: 7/20, Batch: 2000/5000
# Accumulated loss: 2.4946e-04
# Epoch: 7/20, Batch: 2500/5000
# Accumulated loss: 2.4917e-04
# Epoch: 7/20, Batch: 3000/5000
# Accumulated loss: 2.4856e-04
# Epoch: 7/20, Batch: 3500/5000
# Accumulated loss: 2.4967e-04
# Epoch: 7/20, Batch: 4000/5000
# Accumulated loss: 2.5008e-04
# Epoch: 7/20, Batch: 4500/5000
# Accumulated loss: 2.5016e-04
# Epoch: 7/20, Batch: 5000/5000
# Accumulated loss: 2.4995e-04
# Train loss: 2.4995e-04
# torch.Size([1000, 80])
# Test loss: 4.2147e-04
# ===========>
# Epoch: 8/20, Batch: 500/5000
# Accumulated loss: 2.4083e-04
# Epoch: 8/20, Batch: 1000/5000
# Accumulated loss: 2.3981e-04
# Epoch: 8/20, Batch: 1500/5000
# Accumulated loss: 2.3999e-04
# Epoch: 8/20, Batch: 2000/5000
# Accumulated loss: 2.4002e-04
# Epoch: 8/20, Batch: 2500/5000
# Accumulated loss: 2.3958e-04
# Epoch: 8/20, Batch: 3000/5000
# Accumulated loss: 2.3974e-04
# Epoch: 8/20, Batch: 3500/5000
# Accumulated loss: 2.4074e-04
# Epoch: 8/20, Batch: 4000/5000
# Accumulated loss: 2.4067e-04
# Epoch: 8/20, Batch: 4500/5000
# Accumulated loss: 2.4098e-04
# Epoch: 8/20, Batch: 5000/5000
# Accumulated loss: 2.4139e-04
# Train loss: 2.4139e-04
# torch.Size([1000, 80])
# Test loss: 4.1177e-04
# ===========>
# Epoch: 9/20, Batch: 500/5000
# Accumulated loss: 2.3203e-04
# Epoch: 9/20, Batch: 1000/5000
# Accumulated loss: 2.3179e-04
# Epoch: 9/20, Batch: 1500/5000
# Accumulated loss: 2.3231e-04
# Epoch: 9/20, Batch: 2000/5000
# Accumulated loss: 2.3310e-04
# Epoch: 9/20, Batch: 2500/5000
# Accumulated loss: 2.3370e-04
# Epoch: 9/20, Batch: 3000/5000
# Accumulated loss: 2.3438e-04
# Epoch: 9/20, Batch: 3500/5000
# Accumulated loss: 2.3468e-04
# Epoch: 9/20, Batch: 4000/5000
# Accumulated loss: 2.3478e-04
# Epoch: 9/20, Batch: 4500/5000
# Accumulated loss: 2.3478e-04
# Epoch: 9/20, Batch: 5000/5000
# Accumulated loss: 2.3483e-04
# Train loss: 2.3483e-04
# torch.Size([1000, 80])
# Test loss: 4.0774e-04
# ===========>
# Epoch: 20/20, Batch: 3000/5000
# Accumulated loss: 2.0045e-04
# Epoch: 20/20, Batch: 3500/5000
# Accumulated loss: 1.9977e-04
# Epoch: 20/20, Batch: 4000/5000
# Accumulated loss: 2.0012e-04
# Epoch: 20/20, Batch: 4500/5000
# Accumulated loss: 2.0029e-04
# Epoch: 20/20, Batch: 5000/5000
# Accumulated loss: 2.0045e-04
# Train loss: 2.0045e-04
# torch.Size([1000, 80])
# Test loss: 3.9025e-04

# %%
def plot_loss():
    plt.figure(figsize=(8, 6))
    plt.plot(train_loss_hist[1:], 'b')
    plt.plot(test_loss_hist[1:], 'r')
plot_loss()

# %%
def jaccard_dist(embedding1, embedding2):
    return 1 - np.sum(np.minimum(embedding1, embedding2)) / np.sum(np.maximum(embedding1, embedding2)) 
    
def pair_dist(fp, N, embedding_time_fp, embedding_fp, dist_fp):
    seq = torch.zeros((N, 4, SEQ_LEN))
    cnt = 0
    seq_ids = []
    with open(fp) as f:
        while True:
            next_n = list(islice(f, 2))
            if not next_n:
                break
            seq_id = next_n[0].strip()[1:]
            read = next_n[1].strip()
            seq_ids.append(seq_id)
            for i, c in enumerate(read):
                seq[cnt, atcg_map.get(c, 0), i] = 1.0
            cnt += 1
#     net.eval()
    time1 = time.time()
    embeddings = net.forward_one_side(Variable(seq)).data.numpy()
    time2 = time.time()
    with open(embedding_time_fp, 'w') as fo:
        elapsed_time = time2 - time1
        fo.write('{:.2f}s\n'.format(elapsed_time))
    print(embeddings.shape)
    embeddings.tofile(embedding_fp, sep=',', format='%.4e')
    with open(dist_fp, 'w') as fo:
        for i in range(N):
            for j in range(N):
                if i < j:
                    fo.write('{}-{}\t{:.4f}\n'.format(
                        seq_ids[i], seq_ids[j],
                        jaccard_dist(embeddings[i],
                                     embeddings[j])))

# %%
def my_plot(align_dist_df, x_dist_df, x_name, fp):
    fig, ax = plt.subplots(figsize=(10,10))
    ax.tick_params(axis='both', which='major', labelsize=15)
    hb = ax.hexbin(align_dist_df[1], x_dist_df[1], 
                   gridsize=200, bins='log', cmap='Blues', extent=(0, 1, 0, 1),
                   vmin=0, vmax=4)
    ax.plot(np.linspace(0, 1, 100), np.linspace(0, 1, 100), 'r')
    ax.set_xlabel('alignment distance', fontsize=20)
    ax.set_ylabel(x_name, fontsize=20)
    ax.set_title(os.path.splitext(fp)[0], fontsize=26)
    
    cbar_ax = fig.add_axes([0.95, 0.1, 0.05, 0.8])
    cbar_ax.tick_params(axis='both', which='major', labelsize=15)
    cbar = fig.colorbar(hb, cax=cbar_ax)
    cbar.set_label('log10(count + 1)', fontsize=20)
    fig.savefig(fp, bbox_inches='tight')
#     plt.close()
    
def mean_square_error(align_dist_df, x_dist_df, fp):
    with open(fp, 'w') as fo:
        me = np.mean(np.power(align_dist_df.values[:, 1] - x_dist_df.values[:, 1], 2))
        print("Mean Square Error: {:.4e}".format(me))
        fo.write('{:.4e}'.format(me))

# %%
# # evaluation, Qiita_10052, epoch 20, weight off
# torch.save(net.cpu(), './{}/weight/off/siamese.pkl'.format(DATA_SET))
# for i in range(10):
#     print(i)
#     pair_dist('./{}/sample/{}.fa'.format(DATA_SET, i), EVAL_N, 
#               './{}/weight/off/{}_embedding_time.txt'.format(DATA_SET, i),
#               './{}/weight/off/{}_embedding.txt'.format(DATA_SET, i),
#               './{}/weight/off/{}_dist.txt'.format(DATA_SET, i))
#     nw_df = pd.read_csv('./{}/nw/{}_dist.txt'.format(DATA_SET, i), sep='\t', header=None)
#     my_df = pd.read_csv('./{}/weight/off/{}_dist.txt'.format(DATA_SET, i), sep='\t', header=None)
#     my_plot(nw_df, my_df, 
#             x_name='siamese', 
#             fp='./{}/weight/off/{}.png'.format(DATA_SET, i))
#     mean_square_error(nw_df, my_df, './{}/weight/off/{}_MSE.txt'.format(DATA_SET, i))
    
# # evaluation, Qiita_10052, epoch 20, weight on
# torch.save(net.cpu(), './{}/weight/on/siamese.pkl'.format(DATA_SET))
# for i in range(10):
#     print(i)
#     pair_dist('./{}/sample/{}.fa'.format(DATA_SET, i), EVAL_N, 
#               './{}/weight/on/{}_embedding_time.txt'.format(DATA_SET, i),
#               './{}/weight/on/{}_embedding.txt'.format(DATA_SET, i),
#               './{}/weight/on/{}_dist.txt'.format(DATA_SET, i))
#     nw_df = pd.read_csv('./{}/nw/{}_dist.txt'.format(DATA_SET, i), sep='\t', header=None)
#     my_df = pd.read_csv('./{}/weight/on/{}_dist.txt'.format(DATA_SET, i), sep='\t', header=None)
#     my_plot(nw_df, my_df, 
#             x_name='siamese', 
#             fp='./{}/weight/on/{}.png'.format(DATA_SET, i))
#     mean_square_error(nw_df, my_df, './{}/weight/on/{}_MSE.txt'.format(DATA_SET, i))

# evaluation, epoch 200
torch.save(net.cpu(), './{}/siamese/siamese.pkl'.format(DATA_SET))
for i in range(10):
    print(i)
    pair_dist('./{}/sample/{}.fa'.format(DATA_SET, i), EVAL_N, 
              './{}/siamese/{}_embedding_time.txt'.format(DATA_SET, i),
              './{}/siamese/{}_embedding.txt'.format(DATA_SET, i),
              './{}/siamese/{}_dist.txt'.format(DATA_SET, i))
    nw_df = pd.read_csv('./{}/nw/{}_dist.txt'.format(DATA_SET, i), sep='\t', header=None)
    my_df = pd.read_csv('./{}/siamese/{}_dist.txt'.format(DATA_SET, i), sep='\t', header=None)
    my_plot(nw_df, my_df, 
            x_name='siamese', 
            fp='./{}/siamese/{}.png'.format(DATA_SET, i))
    mean_square_error(nw_df, my_df, './{}/siamese/{}_MSE.txt'.format(DATA_SET, i))
# Out:
# /usr/local/lib/python3.5/dist-packages/torch/serialization.py:147: UserWarning: Couldn't retrieve source code for container of type SiameseNetwork. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/local/lib/python3.5/dist-packages/torch/serialization.py:147: UserWarning: Couldn't retrieve source code for container of type MaxMinout. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 0
# (2000, 80)
# Mean Square Error: 4.0110e-04
# 1
# (2000, 80)
# Mean Square Error: 3.5793e-04
# 2
# (2000, 80)
# Mean Square Error: 3.7606e-04
# 3
# (2000, 80)
# Mean Square Error: 3.8065e-04
# 4
# (2000, 80)
# Mean Square Error: 4.0049e-04
# 5
# (2000, 80)
# Mean Square Error: 3.7731e-04
# 6
# (2000, 80)
# Mean Square Error: 3.7026e-04
# 7
# (2000, 80)
# Mean Square Error: 3.8790e-04
# 8
# (2000, 80)
# Mean Square Error: 3.8340e-04
# 9
# (2000, 80)
# Mean Square Error: 3.6963e-04
